# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
roba_ar =np.array([[2, 5, 3, 2, 3, 6, 4, 3, 0, 9],
                    [2, 0, 3, 2, 3, 5, 4, 3, 0, 4],
                    [2, 5, 3, 2, 5, 6, 4, 9, 0, 0]])
roba
# Out:
# [[2, 5, 3, 2, 3, 6, 4, 3, 0, 9],
#  [2, 0, 3, 2, 3, 5, 4, 3, 0, 4],
#  [2, 5, 3, 2, 5, 6, 4, 9, 0, 0]]

# %%
#avg = media istantanea al tempo t tra gli esperimenti
avg = roba_ar.mean(axis=0)
plt.plot(roba_ar.T)
plt.plot(avg, "--", label="avg")
plt.legend()

# %%
#roba cs, reward cumulativa al tempo t per ogni esperimento
# roba_cs_avg, reward cumulativa media al tempo t tra gli esperimenti
roba_cs = roba_ar.cumsum(axis=1)
roba_cs_avg = roba_cs.mean(axis=0)
roba_cs, roba_cs_avg
# Out:
# (array([[ 2,  7, 10, 12, 15, 21, 25, 28, 28, 37],
#         [ 2,  2,  5,  7, 10, 15, 19, 22, 22, 26],
#         [ 2,  7, 10, 12, 17, 23, 27, 36, 36, 36]]),
#  array([ 2.        ,  5.33333333,  8.33333333, 10.33333333, 14.        ,
#         19.66666667, 23.66666667, 28.66666667, 28.66666667, 33.        ]))

# %%
#plottino
plt.plot(roba_cs.T)
plt.plot(roba_cs_avg,"--",  label="avg")
plt.legend()
